# %% [markdown]
# ### This lab has two parts:

# %% [markdown]
# **PART 1: Bicycle Hire data: Read two solutions and write a third:**
#
# - There are two solved examples (Tasks 1 and 2) that use Cycle Hire API and then a list of questions you can try answering by looking at the data.
# - if you run out of tasks feel free to come up with your own.
#
# **PART 2:**
#
# Pick one of the listed APIs and:
#
# 1. Get data from it
# 2. Represent that data as dictionaries or objects
# 3. Invent 1-2 business questions and answer them using your code

# %% [markdown]
# Notes:
# response.json() ---> Will return you data as json (basically a dictionary)
# response.text ---> Useful only for printing all data, Will return data as formatted string, but you can't treat it as a dictionary
#
# Notes:
# Use Chrome web browser and install this JSON Viewer extension to preview JSON in a more readable format: https://chrome.google.com/webstore/detail/json-viewer/gbmdgpbipfallnflgajpaliibnhdgobh

# %% [markdown]
# # Part 1

# %% [markdown]
# ### Bicycle Scheme API Reference:

# %% [markdown]
# We'll use two API calls:
#
# **PERMANENT STATION INFORMATION**: detailed not-changing info about stations (eg. their intended size, location). Use it to get info about all stations in format:
#
# ```
# {
#         "station_id": "1727",
#         "name": "Causewayside",
#         "address": "Causewayside, Edinburgh, EH9 1PR",
#         "lat": 55.93650603148236,
#         "lon": -3.1801663476151134,
#         "capacity": 15
#       }
# ```
#
# **LIVE-UPDATED STATION STATUS**: time relevant (refreshed every 10s) info about current status of the bicycle docking stations right now. Use it to get info about all stations in format:
#
# ```
# {
#         "station_id": "1727",
#         "is_installed": 1,
#         "is_renting": 1,
#         "is_returning": 1,
#         "last_reported": 1571174615,
#         "num_bikes_available": 3,
#         "num_docks_available": 12
#       }
#
# ```
#
# **Documentation:**
#
# https://edinburghcyclehire.com/open-data/realtime
#
# **Full responses of the calls:**
#
# https://gbfs.urbansharing.com/edinburghcyclehire.com/station_information.json
#
# ```
# {
#   "last_updated": 1571174713,
#   "ttl": 10,
#   "data": {
#     "stations": [
#       {
#         "station_id": "1727",
#         "name": "Causewayside",
#         "address": "Causewayside, Edinburgh, EH9 1PR",
#         "lat": 55.93650603148236,
#         "lon": -3.1801663476151134,
#         "capacity": 15
#       },
#       {
#         "station_id": "1726",
#         "name": "Simon Square",
#         "address": "Simon Square, Edinburgh, EH8 9HP",
#         "lat": 55.94485886752089,
#         "lon": -3.182589723460069,
#         "capacity": 13
#       },
# ```
#
# https://gbfs.urbansharing.com/edinburghcyclehire.com/station_status.json
#
#
# ```
#   {
#   "last_updated": 1571174615,
#   "ttl": 10,
#   "data": {
#     "stations": [
#       {
#         "station_id": "1727",
#         "is_installed": 1,
#         "is_renting": 1,
#         "is_returning": 1,
#         "last_reported": 1571174615,
#         "num_bikes_available": 3,
#         "num_docks_available": 12
#       },
#       {
#         "station_id": "1726",
#         "is_installed": 1,
#         "is_renting": 1,
#         "is_returning": 1,
#         "last_reported": 1571174615,
#         "num_bikes_available": 5,
#         "num_docks_available": 8
#       },
# ```

# %% [markdown]
# ## Some starting code: Here are two functions for you to get the data.
#
# No need to edit those, or to even understand them. Just run these cells, so that you can use `get_all_stations_info()` and `get_all_stations_status()` to get the lists of dictionaries, with data about bicycle docking stations.

# %%
import requests
import pprint as pp
    

# here are two functions that you do not need to undertsand just now (but do try later!)
# just have a look at their outputs below:L

def get_all_stations_info():
    # you can see it in yoru briwser by going to: 
#   # https://gbfs.urbansharing.com/edinburghcyclehire.com/station_information.json

    response_station_information = requests.request("GET", "https://gbfs.urbansharing.com/edinburghcyclehire.com/station_information.json")
    stations_info = response_station_information.json()['data']['stations']
    return stations_info

def get_all_stations_status():
    # you can see it in yoru briwser by going to: 
    # https://gbfs.urbansharing.com/edinburghcyclehire.com/station_status.json
    
    response_station_status = requests.request("GET", "https://gbfs.urbansharing.com/edinburghcyclehire.com/station_status.json")
    stations_status = response_station_status.json()['data']['stations']
    return stations_status

# %% [markdown]
# Let's call these functions, so that you see what they return:

# %%
infos = get_all_stations_info()
pp.pprint(infos)
# Out:
# [{'address': 'Picady Place',
#   'capacity': 21,
#   'lat': 55.95653524179326,
#   'lon': -3.1862476120746805,
#   'name': 'Picardy Place',
#   'station_id': '2268'},
#  {'address': 'Bridge St',
#   'capacity': 29,
#   'lat': 55.94396074176487,
#   'lon': -3.058306836702485,
#   'name': 'Musselburgh Brunton Hall',
#   'station_id': '2265'},
#  {'address': 'Musselborough North High Street opposite Harbour Road',
#   'capacity': 24,
#   'lat': 55.94388031687606,
#   'lon': -3.0667539162178628,
#   'name': 'Musselburgh Lidl',
#   'station_id': '2263'},
#  {'address': '165 Leith Walk',
#   'capacity': 31,
#   'lat': 55.96791807044289,
#   'lon': -3.1735862970647304,
#   'name': 'Leith Walk North',
#   'station_id': '2259'},
#  {'address': 'Shore Rd, South Queensferry EH30 9SQ',
#   'capacity': 15,
#   'lat': 55.992957267668345,
#   'lon': -3.4071562055591187,
#   'name': 'Port Edgar Marina',
#   'station_id': '1877'},
#  {'address': 'Ferrymuir, South Queensferry EH30 9QZ',
#   'capacity': 12,
#   'lat': 55.983766187891035,
#   'lon': -3.401351801602175,
#   'name': 'Tesco Ferrymuir',
#   'station_id': '1874'},
#  {'address': 'Scotstoun House, South Queensferry EH30 9SE',
#   'capacity': 12,
#   'lat': 55.98110725959637,
#   'lon': -3.39421060796127,
#   'name': 'Scotstoun House',
#   'station_id': '1871'},
#  {'address': 'South Queensferry EH30 9TA',
#   'capacity': 26,
#   'lat': 55.99052952143077,
#   'lon': -3.3855966605769083,
#   'name': 'Hawes Pier',
#   'station_id': '1870'},
#  {'address': 'South Queensferry, EH30 9RJ',
#   'capacity': 18,
#   'lat': 55.99018214620787,
#   'lon': -3.4046039242787174,
#   'name': 'Hopetoun Road',
#   'station_id': '1869'},
#  {'address': 'South Queensferry EH30 9SF',
#   'capacity': 18,
#   'lat': 55.987743170866025,
#   'lon': -3.40375244599943,
#   'name': 'Forth Bridge Visitors Centre',
#   'station_id': '1868'},
#  {'address': 'The Loan, South Queensferry, EH30 9SD',
#   'capacity': 22,
#   'lat': 55.98989968232655,
#   'lon': -3.397772901929727,
#   'name': 'The Loan',
#   'station_id': '1866'},
#  {'address': 'The Station Masters Office, Station Rd, South Queensferry EH30 '
#              '9JP',
#   'capacity': 14,
#   'lat': 55.98676132611317,
#   'lon': -3.382426853781425,
#   'name': 'Dalmeny Station',
#   'station_id': '1865'},
#  {'address': 'Borrowman Square, South Queensferry EH30 9AS',
#   'capacity': 15,
#   'lat': 55.98260596953824,
#   'lon': -3.3814548980585357,
#   'name': 'Borrowman Square',
#   'station_id': '1864'},
#  {'address': 'Eastfield Rd, Ingliston, Newbridge EH28 8LS',
#   'capacity': 23,
#   'lat': 55.9387919459937,
#   'lon': -3.355556216932513,
#   'name': 'Ingliston Park & Ride',
#   'station_id': '1860'},
#  {'address': 'Edinburgh Park, Edinburgh EH12 9RG',
#   'capacity': 11,
#   'lat': 55.931168715771065,
#   'lon': -3.3144142978056834,
#   'name': 'Edinburgh Park Central',
#   'station_id': '1859'},
#  {'address': 'Duke St, Edinburgh EH6 8HU',
#   'capacity': 43,
#   'lat': 55.96901164826488,
#   'lon': -3.16739470303429,
#   'name': 'Duke Street',
#   'station_id': '1824'},
#  {'address': 'Bainfield Dr, Edinburgh EH11 1JL',
#   'capacity': 25,
#   'lat': 55.94007146917616,
#   'lon': -3.215335840688084,
#   'name': 'Boroughmuir',
#   'station_id': '1823'},
#  {'address': 'Hermiston Gait, Edinburgh, EH11 4DF',
#   'capacity': 20,
#   'lat': 55.927382676939004,
#   'lon': -3.307442444578868,
#   'name': 'Edinburgh Park Station',
#   'station_id': '1822'},
#  {'address': 'Drumsheugh Pl, Edinburgh EH3 7PT',
#   'capacity': 20,
#   'lat': 55.95159412232485,
#   'lon': -3.2123542850940225,
#   'name': 'Drumsheugh Place',
#   'station_id': '1821'},
#  {'address': 'Heriot Watt University, Edinburgh, Currie EH14 4AB',
#   'capacity': 23,
#   'lat': 55.90841344459825,
#   'lon': -3.3287835258168874,
#   'name': 'Heriot Watt - Student Accommodation',
#   'station_id': '1820'},
#  {'address': 'Heriot-Watt University Gait 11, The Avenue, Currie EH14 4AS',
#   'capacity': 20,
#   'lat': 55.9088228790413,
#   'lon': -3.320113285176247,
#   'name': 'Heriot Watt - Edinburgh Business School',
#   'station_id': '1819'},
#  {'address': 'Holyrood Rd, Edinburgh EH8 8AS',
#   'capacity': 35,
#   'lat': 55.951089465236365,
#   'lon': -3.17572460948655,
#   'name': 'Dynamic Earth',
#   'station_id': '1818'},
#  {'address': 'Bankhead Ave, Edinburgh EH11 4DE',
#   'capacity': 17,
#   'lat': 55.926684277487574,
#   'lon': -3.2894811171216665,
#   'name': 'Sighthill - Edinburgh College',
#   'station_id': '1815'},
#  {'address': 'Abbeyhill, Edinburgh, EH8 8EB',
#   'capacity': 20,
#   'lat': 55.95524788917224,
#   'lon': -3.1722162800950704,
#   'name': 'Abbeyhill',
#   'station_id': '1814'},
#  {'address': '24 Milton Rd E, Edinburgh, EH15 2PP',
#   'capacity': 21,
#   'lat': 55.94406627599551,
#   'lon': -3.0985614794416128,
#   'name': 'Milton Road - Edinburgh College',
#   'station_id': '1813'},
#  {'address': 'Royal Edinburgh Hospital, Morningside Pl, Edinburgh EH10 5HF',
#   'capacity': 23,
#   'lat': 55.92781815597736,
#   'lon': -3.2133077222032247,
#   'name': 'Royal Edinburgh Hospital',
#   'station_id': '1809'},
#  {'address': 'Gorgie Rd, Edinburgh EH11 2NP',
#   'capacity': 36,
#   'lat': 55.9387414422504,
#   'lon': -3.2299092549009023,
#   'name': 'Gorgie Road',
#   'station_id': '1808'},
#  {'address': 'Edinburgh, EH4 6GX',
#   'capacity': 20,
#   'lat': 55.969442746098885,
#   'lon': -3.3072587984723745,
#   'name': "Gamekeeper's Road",
#   'station_id': '1807'},
#  {'address': 'Joppa Road, Edinburgh, EH15 2LX',
#   'capacity': 38,
#   'lat': 55.94894930668582,
#   'lon': -3.0947272616547252,
#   'name': 'Joppa',
#   'station_id': '1800'},
#  {'address': 'Riversdale Crescent, Edinburgh EH12 5XN',
#   'capacity': 20,
#   'lat': 55.94479128084842,
#   'lon': -3.243673010460725,
#   'name': 'Murrayfield',
#   'station_id': '1799'},
#  {'address': 'Chambers St, Edinburgh EH1 1JF',
#   'capacity': 22,
#   'lat': 55.94760044619224,
#   'lon': -3.1889197367352153,
#   'name': 'Chambers Street',
#   'station_id': '1798'},
#  {'address': '50 Corstorphine Rd, Edinburgh EH12 6JQ',
#   'capacity': 18,
#   'lat': 55.945045875212095,
#   'lon': -3.250881447188249,
#   'name': 'Ellersly Road',
#   'station_id': '1770'},
#  {'address': 'Brunswick Place, Edinburgh EH7 5HU',
#   'capacity': 31,
#   'lat': 55.96085174106396,
#   'lon': -3.180985762469163,
#   'name': 'Brunswick Place',
#   'station_id': '1769'},
#  {'address': 'Thirlestane Road, Edinburgh, EH9 1AY',
#   'capacity': 20,
#   'lat': 55.935323709648124,
#   'lon': -3.198763443819871,
#   'name': 'Thirlestane Road',
#   'station_id': '1768'},
#  {'address': 'Bruntsfield Terrace, Edinburgh, EH10 4EX',
#   'capacity': 24,
#   'lat': 55.937123239991095,
#   'lon': -3.206431879393449,
#   'name': 'Bruntsfield Links',
#   'station_id': '1767'},
#  {'address': 'Balgreen Road, Edinburgh, EH12 5XQ,',
#   'capacity': 29,
#   'lat': 55.938941745489494,
#   'lon': -3.251110776059022,
#   'name': 'Balgreen Road',
#   'station_id': '1766'},
#  {'address': '90 Haymarket Terrace, Edinburgh EH12 5LQ',
#   'capacity': 20,
#   'lat': 55.946063966641006,
#   'lon': -3.2230240243595745,
#   'name': 'Haymarket Terrace',
#   'station_id': '1765'},
#  {'address': 'Craigleith Road, Edinburgh, EH4 2EG',
#   'capacity': 25,
#   'lat': 55.95657629337518,
#   'lon': -3.237939788691392,
#   'name': 'Craigleith Road',
#   'station_id': '1764'},
#  {'address': 'Comely Bank Road, Edinburgh EH4 1DW',
#   'capacity': 16,
#   'lat': 55.95941012836135,
#   'lon': -3.2156613606136943,
#   'name': 'Comely Bank Road',
#   'station_id': '1763'},
#  {'address': 'Queen Margaret University Way, Musselburgh EH21 6UU',
#   'capacity': 17,
#   'lat': 55.931980482636575,
#   'lon': -3.0731046336811687,
#   'name': 'Queen Margaret University',
#   'station_id': '1758'},
#  {'address': '4 Meggetland Wynd, Edinburgh EH14 1XN',
#   'capacity': 15,
#   'lat': 55.92758664038103,
#   'lon': -3.2336710530441906,
#   'name': 'Meggetland',
#   'station_id': '1757'},
#  {'address': 'Porterfield Road, Edinburgh, EH4 2PD',
#   'capacity': 17,
#   'lat': 55.96283984266853,
#   'lon': -3.234135938375289,
#   'name': 'Western General Hospital',
#   'station_id': '1756'},
#  {'address': 'Roseburn St, Edinburgh EH12 5PE',
#   'capacity': 22,
#   'lat': 55.94191081116495,
#   'lon': -3.2378003138226177,
#   'name': 'Murrayfield Tram',
#   'station_id': '1754'},
#  {'address': '38 Comely Bank Rd, Edinburgh EH4 1AW',
#   'capacity': 17,
#   'lat': 55.959536249717715,
#   'lon': -3.223434402338853,
#   'name': 'Waitrose Comely Bank',
#   'station_id': '1753'},
#  {'address': 'Crewe Rd South, Edinburgh, EH4 2SP',
#   'capacity': 26,
#   'lat': 55.96264210870907,
#   'lon': -3.2319155472439434,
#   'name': 'IGMM - Western General',
#   'station_id': '1752'},
#  {'address': 'Dean Park St, Edinburgh EH4 1JS',
#   'capacity': 18,
#   'lat': 55.957278012740645,
#   'lon': -3.2142853873890544,
#   'name': 'Dean Street',
#   'station_id': '1749'},
#  {'address': 'Colinton Rd, Edinburgh EH10 5DS',
#   'capacity': 18,
#   'lat': 55.933416359161036,
#   'lon': -3.21239711224257,
#   'name': 'Colinton Road',
#   'station_id': '1748'},
#  {'address': 'Silvan House, 231 Corstorphine Rd, Edinburgh EH12 7AT',
#   'capacity': 25,
#   'lat': 55.94166971920444,
#   'lon': -3.271523727766862,
#   'name': 'Corstorphine Road',
#   'station_id': '1747'},
#  {'address': 'Royal Cres, Edinburgh EH3 6PZ',
#   'capacity': 15,
#   'lat': 55.96037972054591,
#   'lon': -3.1954703369027584,
#   'name': 'Scotland Street',
#   'station_id': '1745'},
#  {'address': 'Morningside Rd, Edinburgh EH10 4QQ',
#   'capacity': 20,
#   'lat': 55.927985349796536,
#   'lon': -3.209749771944871,
#   'name': 'Morningside Road',
#   'station_id': '1744'},
#  {'address': 'Logie Green Rd, Edinburgh EH7 4HF',
#   'capacity': 27,
#   'lat': 55.964058329676064,
#   'lon': -3.1957003611248638,
#   'name': 'Logie Green Road',
#   'station_id': '1743'},
#  {'address': 'Little France, Edinburgh EH16 4SA',
#   'capacity': 17,
#   'lat': 55.921220122613306,
#   'lon': -3.1390755550312406,
#   'name': 'Edinburgh Royal Infirmary',
#   'station_id': '1739'},
#  {'address': 'Edinburgh EH12 5JE',
#   'capacity': 19,
#   'lat': 55.94564841884953,
#   'lon': -3.2318471509140636,
#   'name': 'Wester Coates Terrace',
#   'station_id': '1738'},
#  {'address': 'Inverleith Terrace, Edinburgh EH3 5NS',
#   'capacity': 23,
#   'lat': 55.964117879889585,
#   'lon': -3.2020947474163677,
#   'name': 'Inverleith Row',
#   'station_id': '1737'},
#  {'address': 'Pleasance, Edinburgh EH8 9TJ',
#   'capacity': 20,
#   'lat': 55.947490592969416,
#   'lon': -3.181112126101965,
#   'name': 'Pleasance Courtyard',
#   'station_id': '1731'},
#  {'address': 'East London St, Edinburgh EH7 4BW',
#   'capacity': 25,
#   'lat': 55.95995414501485,
#   'lon': -3.1871977585476543,
#   'name': 'East London Street',
#   'station_id': '1730'},
#  {'address': 'McDonald Rd, Edinburgh EH7 4NS',
#   'capacity': 23,
#   'lat': 55.9640310527501,
#   'lon': -3.1851753729504253,
#   'name': 'McDonald Road',
#   'station_id': '1729'},
#  {'address': 'Kings Road, Portobello, Edinburgh, EH15 1DX',
#   'capacity': 69,
#   'lat': 55.957915406923476,
#   'lon': -3.1183320420902874,
#   'name': 'Portobello - Kings Road',
#   'station_id': '1728'},
#  {'address': 'Causewayside, Edinburgh, EH9 1PR',
#   'capacity': 21,
#   'lat': 55.93650603148236,
#   'lon': -3.1801663476151134,
#   'name': 'Causewayside',
#   'station_id': '1727'},
#  {'address': 'Simon Square, Edinburgh, EH8 9HP',
#   'capacity': 20,
#   'lat': 55.94485886752089,
#   'lon': -3.182589723460069,
#   'name': 'Simon Square',
#   'station_id': '1726'},
#  {'address': 'Corstorphine Road, Edinburgh, EH12 6TS',
#   'capacity': 15,
#   'lat': 55.94211534619251,
#   'lon': -3.2692867654484417,
#   'name': 'Edinburgh Zoo',
#   'station_id': '1725'},
#  {'address': 'Cramond Harbour, Edinburgh, EH4 6NU',
#   'capacity': 37,
#   'lat': 55.980030767403164,
#   'lon': -3.300641788832536,
#   'name': 'Cramond Foreshore',
#   'station_id': '1722'},
#  {'address': 'High Riggs, Edinburgh, EH3 9RP',
#   'capacity': 25,
#   'lat': 55.944248052468346,
#   'lon': -3.2031045991104747,
#   'name': 'Tollcross',
#   'station_id': '1721'},
#  {'address': 'Airlie Place, Edinburgh, EH3 5DT',
#   'capacity': 20,
#   'lat': 55.9607624081837,
#   'lon': -3.201278014771333,
#   'name': 'Dundas Street',
#   'station_id': '1720'},
#  {'address': 'Haymarket Terrace, Edinburgh, EH12 5EY',
#   'capacity': 20,
#   'lat': 55.94556945067266,
#   'lon': -3.21818468327956,
#   'name': 'Haymarket Station',
#   'station_id': '1102'},
#  {'address': 'Marchmont Crescent, Edinburgh, EH9 1HD',
#   'capacity': 25,
#   'lat': 55.936431918148195,
#   'lon': -3.194150044314256,
#   'name': 'Marchmont Crescent',
#   'station_id': '1098'},
#  {'address': 'Gladstone Terrace, Edinburgh, EH9 1LU',
#   'capacity': 12,
#   'lat': 55.93796327344498,
#   'lon': -3.185021145932069,
#   'name': 'Gladstone Terrace',
#   'station_id': '1097'},
#  {'address': 'West Crosscauseway, Edinburgh, EH8 9AT',
#   'capacity': 25,
#   'lat': 55.9438359841253,
#   'lon': -3.1849514084976818,
#   'name': 'West Crosscauseway',
#   'station_id': '1096'},
#  {'address': '75 Belford Rd, Edinburgh EH4 3DR',
#   'capacity': 19,
#   'lat': 55.95197357717703,
#   'lon': -3.226124804664096,
#   'name': 'Belford Road',
#   'station_id': '1093'},
#  {'address': 'Dalry Rd, Edinburgh EH11 2EF',
#   'capacity': 16,
#   'lat': 55.94179129688128,
#   'lon': -3.2224153095964994,
#   'name': 'Dalry Road Lidl',
#   'station_id': '1092'},
#  {'address': 'Holyrood Rd, Edinburgh EH8 8AQ',
#   'capacity': 26,
#   'lat': 55.94955950619123,
#   'lon': -3.180413257527789,
#   'name': 'Holyrood Road',
#   'station_id': '1091'},
#  {'address': 'Opposite 34 Hillside Cres Edinburgh EH7 5EF',
#   'capacity': 22,
#   'lat': 55.95787194536338,
#   'lon': -3.1758883709196652,
#   'name': 'Hillside Crescent',
#   'station_id': '1090'},
#  {'address': 'Roseburn Street, Edinburgh',
#   'capacity': 22,
#   'lat': 55.94442555452843,
#   'lon': -3.234497716594433,
#   'name': 'Roseburn Street',
#   'station_id': '1055'},
#  {'address': 'Nicolson St, Edinburgh EH8 9DW',
#   'capacity': 23,
#   'lat': 55.94664279961712,
#   'lon': -3.1854745859388913,
#   'name': 'Surgeons Hall',
#   'station_id': '1052'},
#  {'address': 'Warrender Park Rd, Edinburgh EH9 1ES',
#   'capacity': 15,
#   'lat': 55.93836921723555,
#   'lon': -3.1980326885466184,
#   'name': 'Warrender Park Road',
#   'station_id': '1051'},
#  {'address': '150 Morrison St, Edinburgh EH3 8EE',
#   'capacity': 25,
#   'lat': 55.94607055533778,
#   'lon': -3.2103963310007657,
#   'name': 'EICC',
#   'station_id': '1050'},
#  {'address': 'Murchison House, 10 Max Born Cres, Edinburgh EH9 3BF',
#   'capacity': 14,
#   'lat': 55.92446420087144,
#   'lon': -3.1787315124754514,
#   'name': 'Kings Buildings - Murchison House',
#   'station_id': '1042'},
#  {'address': 'Lothian Road, Edinburgh, EH1 2EA',
#   'capacity': 46,
#   'lat': 55.947409199207115,
#   'lon': -3.2057654971365537,
#   'name': 'Lothian Road',
#   'station_id': '1039'},
#  {'address': 'South Trinity Road, Edinburgh, EH5 3NR',
#   'capacity': 31,
#   'lat': 55.97132539148155,
#   'lon': -3.207963567424258,
#   'name': 'South Trinity Road',
#   'station_id': '1038'},
#  {'address': '127 George St, Edinburgh EH2 4JN',
#   'capacity': 7,
#   'lat': 55.95261935955009,
#   'lon': -3.205678007970846,
#   'name': 'Eden Locke - Aparthotel (RESIDENTS ONLY)',
#   'station_id': '1031'},
#  {'address': '123 Grove St, Edinburgh EH3 8AA',
#   'capacity': 6,
#   'lat': 55.94380585491596,
#   'lon': -3.211238456749925,
#   'name': 'Fountain Court  - Apartments (RESIDENTS ONLY)',
#   'station_id': '1030'},
#  {'address': '122 High Street, Edinburgh, EH1 1SG',
#   'capacity': 17,
#   'lat': 55.949797565633276,
#   'lon': -3.1877950320129003,
#   'name': 'Hunter Square',
#   'station_id': '1028'},
#  {'address': '3 Dundee Terrace, edinburgh, EH11BY',
#   'capacity': 17,
#   'lat': 55.93970989541296,
#   'lon': -3.2205889336679547,
#   'name': 'Dundee Terrace',
#   'station_id': '1025'},
#  {'address': 'Meadow Place, edinburgh, EH91JZ',
#   'capacity': 25,
#   'lat': 55.940237631689435,
#   'lon': -3.194640214184801,
#   'name': 'Meadow Place',
#   'station_id': '1024'},
#  {'address': 'outside 86-88 Grassmarket, Edinburgh, EH1 2JR',
#   'capacity': 14,
#   'lat': 55.947097278583385,
#   'lon': -3.1972457326126005,
#   'name': 'Grassmarket',
#   'station_id': '1019'},
#  {'address': 'Crichton Street, Edinburgh, EH8 9LE',
#   'capacity': 18,
#   'lat': 55.94478427951007,
#   'lon': -3.186906245433761,
#   'name': 'Crichton Street',
#   'station_id': '1017'},
#  {'address': 'Leith Walk',
#   'capacity': 18,
#   'lat': 55.96503980507732,
#   'lon': -3.1766864147848537,
#   'name': 'Leith Walk',
#   'station_id': '358'},
#  {'address': '30 Queensferry Road',
#   'capacity': 17,
#   'lat': 55.95508276879095,
#   'lon': -3.2236342639564555,
#   'name': 'Orchard Brae House',
#   'station_id': '349'},
#  {'address': 'Lady Lawson Street',
#   'capacity': 20,
#   'lat': 55.94676648672239,
#   'lon': -3.2020378290551434,
#   'name': 'Castle Terrace',
#   'station_id': '296'},
#  {'address': 'Castle Street',
#   'capacity': 24,
#   'lat': 55.951500737349754,
#   'lon': -3.2031839065252825,
#   'name': 'Castle Street',
#   'station_id': '289'},
#  {'address': 'Ocean Drive',
#   'capacity': 44,
#   'lat': 55.981286014792985,
#   'lon': -3.176351263805259,
#   'name': 'Ocean Terminal',
#   'station_id': '285'},
#  {'address': 'Sciennes, Edinburgh EH9 1NH',
#   'capacity': 24,
#   'lat': 55.939809466328285,
#   'lon': -3.182738850746432,
#   'name': 'Meadows East',
#   'station_id': '265'},
#  {'address': '18 Holyrood Park Road',
#   'capacity': 42,
#   'lat': 55.94008064125911,
#   'lon': -3.171746866852459,
#   'name': 'Pollock Halls',
#   'station_id': '264'},
#  {'address': 'Broughton Road',
#   'capacity': 28,
#   'lat': 55.96280408759764,
#   'lon': -3.196283585062929,
#   'name': 'Canonmills',
#   'station_id': '262'},
#  {'address': 'Lauriston Place',
#   'capacity': 23,
#   'lat': 55.944771652335476,
#   'lon': -3.1972658564195626,
#   'name': 'Lauriston Place',
#   'station_id': '260'},
#  {'address': 'St Andrew Square',
#   'capacity': 13,
#   'lat': 55.95490573198223,
#   'lon': -3.192443756949956,
#   'name': 'St Andrew Square',
#   'station_id': '259'},
#  {'address': '1, Dean Bank Lane',
#   'capacity': 15,
#   'lat': 55.95856558589723,
#   'lon': -3.2080701822277433,
#   'name': 'Stockbridge',
#   'station_id': '258'},
#  {'address': 'Regent Road',
#   'capacity': 13,
#   'lat': 55.95316433242384,
#   'lon': -3.181682340931843,
#   'name': 'St Andrews House',
#   'station_id': '256'},
#  {'address': 'James Dewar Road',
#   'capacity': 26,
#   'lat': 55.923478807846635,
#   'lon': -3.1753845849070785,
#   'name': 'Kings Building 3',
#   'station_id': '254'},
#  {'address': 'Entrance to Sanderson Building',
#   'capacity': 15,
#   'lat': 55.92320215516664,
#   'lon': -3.1716462453634904,
#   'name': 'Kings Building 2',
#   'station_id': '253'},
#  {'address': 'James Hutton Road',
#   'capacity': 12,
#   'lat': 55.92418540667696,
#   'lon': -3.173830830087809,
#   'name': 'Kings Buildings 1',
#   'station_id': '252'},
#  {'address': 'Waverley Station Concourse',
#   'capacity': 19,
#   'lat': 55.952641035774384,
#   'lon': -3.187526919462357,
#   'name': 'Waverley Station',
#   'station_id': '251'},
#  {'address': 'Entrance to Scottish Government Office',
#   'capacity': 44,
#   'lat': 55.977617152546344,
#   'lon': -3.1741263194576277,
#   'name': 'Victoria Quay',
#   'station_id': '250'},
#  {'address': '116 Fountainbridge',
#   'capacity': 18,
#   'lat': 55.94335692764551,
#   'lon': -3.2092475016246453,
#   'name': 'Fountainbridge',
#   'station_id': '249'},
#  {'address': 'Bristo Square, Potterrow',
#   'capacity': 43,
#   'lat': 55.94583371599285,
#   'lon': -3.189053072075467,
#   'name': 'Bristo Square',
#   'station_id': '248'},
#  {'address': 'Charlotte Square',
#   'capacity': 22,
#   'lat': 55.95233546161639,
#   'lon': -3.2071011721072864,
#   'name': 'Charlotte Square',
#   'station_id': '247'},
#  {'address': 'Dalkeith Road, Edinburgh EH16 5BB',
#   'capacity': 13,
#   'lat': 55.939000247888764,
#   'lon': -3.173923554315593,
#   'name': 'Royal Commonwealth Pool',
#   'station_id': '246'},
#  {'address': 'Waverley Court, East Market Street',
#   'capacity': 13,
#   'lat': 55.95173449698344,
#   'lon': -3.1841785354060903,
#   'name': 'Waverley Court',
#   'station_id': '225'},
#  {'address': 'High Street',
#   'capacity': 17,
#   'lat': 55.95010933017899,
#   'lon': -3.190257770093808,
#   'name': 'City Chambers',
#   'station_id': '189'},
#  {'address': 'Waverley Bridge',
#   'capacity': 22,
#   'lat': 55.951980756193535,
#   'lon': -3.1918903325579038,
#   'name': 'Waverley Bridge',
#   'station_id': '183'},
#  {'address': 'George Square',
#   'capacity': 36,
#   'lat': 55.94308406301113,
#   'lon': -3.1883110727223993,
#   'name': 'George Square',
#   'station_id': '171'}]

# %%
statuses = get_all_stations_status()
pp.pprint(statuses)
# Out:
# [{'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 21,
#   'station_id': '2268'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 10,
#   'station_id': '2265'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 5,
#   'num_docks_available': 14,
#   'station_id': '2263'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 4,
#   'num_docks_available': 12,
#   'station_id': '2259'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 15,
#   'station_id': '1877'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 4,
#   'num_docks_available': 8,
#   'station_id': '1874'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 2,
#   'num_docks_available': 10,
#   'station_id': '1871'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 8,
#   'num_docks_available': 17,
#   'station_id': '1870'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 2,
#   'num_docks_available': 15,
#   'station_id': '1869'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 2,
#   'num_docks_available': 16,
#   'station_id': '1868'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 5,
#   'num_docks_available': 15,
#   'station_id': '1866'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 3,
#   'num_docks_available': 11,
#   'station_id': '1865'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 2,
#   'num_docks_available': 13,
#   'station_id': '1864'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 2,
#   'num_docks_available': 17,
#   'station_id': '1860'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 5,
#   'station_id': '1859'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 29,
#   'station_id': '1824'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 3,
#   'num_docks_available': 6,
#   'station_id': '1823'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 9,
#   'station_id': '1822'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 17,
#   'station_id': '1821'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 5,
#   'num_docks_available': 18,
#   'station_id': '1820'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 17,
#   'station_id': '1819'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 33,
#   'station_id': '1818'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 2,
#   'num_docks_available': 5,
#   'station_id': '1815'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 11,
#   'station_id': '1814'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 5,
#   'num_docks_available': 13,
#   'station_id': '1813'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 20,
#   'station_id': '1809'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 19,
#   'station_id': '1808'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 2,
#   'num_docks_available': 6,
#   'station_id': '1807'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 2,
#   'num_docks_available': 23,
#   'station_id': '1800'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 7,
#   'station_id': '1799'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 20,
#   'station_id': '1798'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 4,
#   'num_docks_available': 8,
#   'station_id': '1770'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 18,
#   'station_id': '1769'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 3,
#   'num_docks_available': 17,
#   'station_id': '1768'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 17,
#   'station_id': '1767'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 10,
#   'station_id': '1766'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 2,
#   'num_docks_available': 17,
#   'station_id': '1765'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 4,
#   'num_docks_available': 8,
#   'station_id': '1764'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 4,
#   'num_docks_available': 9,
#   'station_id': '1763'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 4,
#   'num_docks_available': 13,
#   'station_id': '1758'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 9,
#   'station_id': '1757'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 3,
#   'num_docks_available': 11,
#   'station_id': '1756'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 15,
#   'station_id': '1754'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 3,
#   'num_docks_available': 9,
#   'station_id': '1753'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 3,
#   'num_docks_available': 13,
#   'station_id': '1752'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 5,
#   'num_docks_available': 13,
#   'station_id': '1749'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 18,
#   'station_id': '1748'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 15,
#   'station_id': '1747'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 7,
#   'station_id': '1745'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 3,
#   'num_docks_available': 16,
#   'station_id': '1744'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 14,
#   'station_id': '1743'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 3,
#   'num_docks_available': 13,
#   'station_id': '1739'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 8,
#   'station_id': '1738'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 5,
#   'num_docks_available': 13,
#   'station_id': '1737'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 3,
#   'num_docks_available': 17,
#   'station_id': '1731'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 22,
#   'station_id': '1730'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 12,
#   'station_id': '1729'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 4,
#   'num_docks_available': 46,
#   'station_id': '1728'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 3,
#   'num_docks_available': 18,
#   'station_id': '1727'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 2,
#   'num_docks_available': 8,
#   'station_id': '1726'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 12,
#   'station_id': '1725'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 17,
#   'station_id': '1722'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 22,
#   'station_id': '1721'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 4,
#   'num_docks_available': 15,
#   'station_id': '1720'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 3,
#   'num_docks_available': 17,
#   'station_id': '1102'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 2,
#   'num_docks_available': 22,
#   'station_id': '1098'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 2,
#   'num_docks_available': 9,
#   'station_id': '1097'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 5,
#   'num_docks_available': 17,
#   'station_id': '1096'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 16,
#   'station_id': '1093'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 3,
#   'num_docks_available': 6,
#   'station_id': '1092'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 3,
#   'num_docks_available': 23,
#   'station_id': '1091'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 3,
#   'num_docks_available': 12,
#   'station_id': '1090'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 7,
#   'station_id': '1055'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 14,
#   'station_id': '1052'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 3,
#   'num_docks_available': 10,
#   'station_id': '1051'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 4,
#   'num_docks_available': 21,
#   'station_id': '1050'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 2,
#   'num_docks_available': 12,
#   'station_id': '1042'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 43,
#   'station_id': '1039'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 18,
#   'station_id': '1038'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 7,
#   'station_id': '1031'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 6,
#   'station_id': '1030'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 9,
#   'station_id': '1028'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 2,
#   'num_docks_available': 11,
#   'station_id': '1025'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 5,
#   'num_docks_available': 20,
#   'station_id': '1024'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 4,
#   'num_docks_available': 10,
#   'station_id': '1019'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 15,
#   'station_id': '1017'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 5,
#   'num_docks_available': 10,
#   'station_id': '358'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 13,
#   'station_id': '349'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 19,
#   'station_id': '296'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 7,
#   'station_id': '289'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 4,
#   'num_docks_available': 21,
#   'station_id': '285'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 8,
#   'num_docks_available': 16,
#   'station_id': '265'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 40,
#   'station_id': '264'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 15,
#   'station_id': '262'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 21,
#   'station_id': '260'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 8,
#   'station_id': '259'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 5,
#   'num_docks_available': 8,
#   'station_id': '258'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 3,
#   'num_docks_available': 8,
#   'station_id': '256'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 2,
#   'num_docks_available': 24,
#   'station_id': '254'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 12,
#   'station_id': '253'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 2,
#   'num_docks_available': 9,
#   'station_id': '252'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 18,
#   'station_id': '251'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 4,
#   'num_docks_available': 21,
#   'station_id': '250'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 2,
#   'num_docks_available': 14,
#   'station_id': '249'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 34,
#   'station_id': '248'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 2,
#   'num_docks_available': 13,
#   'station_id': '247'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 10,
#   'station_id': '246'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 3,
#   'num_docks_available': 10,
#   'station_id': '225'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 1,
#   'num_docks_available': 16,
#   'station_id': '189'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 0,
#   'num_docks_available': 19,
#   'station_id': '183'},
#  {'is_installed': 1,
#   'is_renting': 1,
#   'is_returning': 1,
#   'last_reported': 1603117743,
#   'num_bikes_available': 3,
#   'num_docks_available': 8,
#   'station_id': '171'}]

# %% [markdown]
# ### SOLVED Task 1 - What is the total capacity of all docking stations in Edinburgh?  (use station info to find out)

# %%
def get_total_capacity():
    all_stations_infos = get_all_stations_info()
    capacities = [ station_info['capacity']
                    for station_info in all_stations_infos
                 ]
    return sum(capacities)

print( "Total Capacity: ", get_total_capacity() )
# Out:
# Total Capacity:  2474

# %% [markdown]
# ### SOLVED Task 2 - How many bicycles are available right now (use station status to find out)

# %%
def get_total_bikes_parked_now():
    all_stations_statuses = get_all_stations_status()


    bikes_parked = [ station_status['num_bikes_available']
                    for station_status in all_stations_statuses
                 ]        
    return sum(bikes_parked)

print( "Bikes Parked now: ", get_total_bikes_parked_now() )
# Out:
# Bikes Parked now:  228

# %% [markdown]
# ### SOLVED Task 3 -  Business wants to place adverts of the largest stations (the ones larger than average). How many stations are we talking about?
#
# Find the number of stations that are above average capacity. Calculate total capacity (you did it already), then find out the average capacity. Finally filter only stations larger than that and count them.
#
# note: Prints are there to show you the process in a clearer way. But it's the return value that counts!

# %%
def get_stations_in_top_10_percent_largest():
    all_stations_infos = get_all_stations_info()

    total_capacity = get_total_capacity()
    print("total_capacity",total_capacity)

    number_of_stations = len(all_stations_infos)
    print("number_of_stations",number_of_stations)
    
    average_capacity = total_capacity / number_of_stations
    print("average capacity is",average_capacity)
    
    stations_in_top_10_percent_largest = [ station_info['capacity']
                    for station_info in all_stations_infos
                    if station_info['capacity'] > average_capacity
                 ]        
    
    return len(stations_in_top_10_percent_largest)

print( "Number of stations larger than average: ", get_stations_in_top_10_percent_largest() )
# Out:
# total_capacity 2474
# number_of_stations 111
# average capacity is 22.28828828828829
# Number of stations larger than average:  43

# %% [markdown]
# Optional addition to task 3: once you understand avbove code, can you Change it so it shows the list of all capacities above average? It will look a bit like this: `[29, 24, 31, 26, 23, 36]` ?

# %% [markdown]
# ### Task 4 - What is the number of docking stations with unknown state? (not having a bike in them, and not waiting for a bike)
#
#
# In the station status we know two things about each docking station: number of usable bikes available there now `num_bikes_available`  and number of empty parking spots available now `num_docks_available`. But we also know the `capacity` that the station was designed for.
#
# When you look at the data carefully, you will see that often the designed `capacity` does not add up to `num_bikes_available` plus `num_docks_available`. That's becuse if a docking pointis broken, or broken bicycle is in it.
#
# Find out how many of these 'zombie' spaces are there in the whole city. How would you do that?

# %%
def get_number_of_docks_not_waiting_and_not_with_a_bike():

    all_stations_infos = get_all_stations_info()
    all_stations_statuses = get_all_stations_status()

    bikes_parked_and_empty_docks = [ station_status['num_bikes_available'] + station_status['num_docks_available']
                    for station_status in all_stations_statuses
                 ]  
    
    nominal_capacity_of_stations = [ station_info['capacity']
                    for station_info in all_stations_infos
                 ]  
    total_bikes_parked_and_empty_docks = sum(bikes_parked_and_empty_docks)
    total_nominal_capacity_of_stations = sum(nominal_capacity_of_stations)
    
    print(total_nominal_capacity_of_stations, total_bikes_parked_and_empty_docks)
    return total_nominal_capacity_of_stations - total_bikes_parked_and_empty_docks

print( "Zombie docks:", get_number_of_docks_not_waiting_and_not_with_a_bike() )
# Out:
# 2474 1874
# Zombie docks: 600

# %% [markdown]
# ### Task 5 - What is average number of bikes available per station

# %%
def get_avg_of_available_bikes_per_station():

    all_stations_statuses = get_all_stations_status()

    bikes_parked = [ station_status['num_bikes_available']
                    for station_status in all_stations_statuses
                 ]  

    total_bikes_parked = sum(bikes_parked)
    number_of_stations = len(all_stations_statuses)
    
    print(total_bikes_parked, number_of_stations)
    return total_bikes_parked / number_of_stations

print( "average number of bikes available per station:", get_avg_of_available_bikes_per_station() )
# Out:
# 219 111
# average number of bikes available per station: 1.972972972972973

# %% [markdown]
# ### Task 6 - What percentage of stations is more than half-empty right now? (how would you calculate that? try to only use get_all_stations_status( ) )

# %%
def get_percent_of_half_empty_stations():

    all_stations_statuses = get_all_stations_status()

    all_half_empty_stations = [ station_status
                    for station_status in all_stations_statuses
                    if station_status['num_bikes_available'] < 3#station_status['num_docks_available']
                 ]  
    
    number_of_half_empty_stations = len(all_stations_statuses)
    number_of_stations = len(all_stations_statuses)

    print(number_of_half_empty_stations, number_of_stations)
    return 100 * number_of_half_empty_stations / number_of_stations

print( "percentage of stations more than half-empty right now:", get_percent_of_half_empty_stations() )
# Out:
# 111 111
# percentage of stations more than half-empty right now: 100.0

# %% [markdown]
# ### Task 7 - Given station id (e.g. 248 is the one next to Business School) print information about it FROM BOTH APIS

# %%
def info_about_station(station_id):
    
    all_stations_infos = get_all_stations_info()
    all_stations_statuses = get_all_stations_status()

    statuses_of_all_stations_with_this_id = [ station_status
                    for station_status in all_stations_statuses
                     if station_status['station_id'] == str(station_id)
                 ]  
    this_station_status = statuses_of_all_stations_with_this_id[0]
    print("this_station_status", this_station_status)
    
    infos_of_all_stations_with_this_id = [ station_info
                for station_info in all_stations_infos
                 if station_info['station_id'] == str(station_id)
         ]  
    this_station_info = infos_of_all_stations_with_this_id[0]
    print("this_station_info", this_station_info)
    print()

    this_station_status.update(this_station_info)
    return this_station_status

pp.pprint(info_about_station(248) )
# Out:
# this_station_status {'station_id': '248', 'is_installed': 1, 'is_renting': 1, 'is_returning': 1, 'last_reported': 1603118709, 'num_bikes_available': 0, 'num_docks_available': 35}
# this_station_info {'station_id': '248', 'name': 'Bristo Square', 'address': 'Bristo Square, Potterrow', 'lat': 55.94583371599285, 'lon': -3.189053072075467, 'capacity': 43}
#
# {'address': 'Bristo Square, Potterrow',
#  'capacity': 43,
#  'is_installed': 1,
#  'is_renting': 1,
#  'is_returning': 1,
#  'last_reported': 1603118709,
#  'lat': 55.94583371599285,
#  'lon': -3.189053072075467,
#  'name': 'Bristo Square',
#  'num_bikes_available': 0,
#  'num_docks_available': 35,
#  'station_id': '248'}

# %% [markdown]
# ### Task 8 - Look at the available data about bicycle parking stations info and status and form a business problem that could be solved with this data. Then solve that problem with code

# %%
# for a givemnprint info about all stations, like "Bristo Square has 3 bikes right now"
# note you'll have to combine both sources of info

def names_of_all_stations_larger_than_average():
    
    all_stations_infos = get_all_stations_info()

    all_stations_capacities = [ station_info['capacity']
                for station_info in all_stations_infos
         ]  
    average_capacity = sum(all_stations_capacities) / len(all_stations_capacities)
    print("average_capacity", average_capacity)

    names_of_above_average_stations = [ station_info['name']
                for station_info in all_stations_infos
                if station_info['capacity'] > average_capacity
         ] 
    print("number of stations above average", len(names_of_above_average_stations))

    return names_of_above_average_stations

print(names_of_all_stations_larger_than_average() )
# Out:
# average_capacity 22.28828828828829
# number of stations above average 43
# ['Musselburgh Brunton Hall', 'Musselburgh Lidl', 'Leith Walk North', 'Hawes Pier', 'Ingliston Park & Ride', 'Duke Street', 'Boroughmuir', 'Heriot Watt - Student Accommodation', 'Dynamic Earth', 'Royal Edinburgh Hospital', 'Gorgie Road', 'Joppa', 'Brunswick Place', 'Bruntsfield Links', 'Balgreen Road', 'Craigleith Road', 'IGMM - Western General', 'Corstorphine Road', 'Logie Green Road', 'Inverleith Row', 'East London Street', 'McDonald Road', 'Portobello - Kings Road', 'Cramond Foreshore', 'Tollcross', 'Marchmont Crescent', 'West Crosscauseway', 'Holyrood Road', 'Surgeons Hall', 'EICC', 'Lothian Road', 'South Trinity Road', 'Meadow Place', 'Castle Street', 'Ocean Terminal', 'Meadows East', 'Pollock Halls', 'Canonmills', 'Lauriston Place', 'Kings Building 3', 'Victoria Quay', 'Bristo Square', 'George Square']

# %% [markdown]
# # Part 2: If you still have time: Pick one of the below APIs: Stocks or IMDB

# %% [markdown]
# Pick one of the listed APIs and:
#
# 1. Get data from it
# 2. Represent that data as dictionaries or objects
# 3. Invent 1-3 business questions and answer them using your code
#
# Agree on your goals first, so that you are on the same page.

# %% [markdown]
# ### Stock Information:

# %% [markdown]
# - this api will require you to create an account (you'll need to gove them youe email)
# - you will be limited to 5 calls a minute and 500 calls a day
#
# Get API key here:  https://www.alphavantage.co/support/#api-key
#
# Docs: https://www.alphavantage.co/documentation/
#
# Look carefully at the URLs, they contain all the details about your question you're asking of API.
#
# for example https://www.alphavantage.co/query?function=FX_DAILY&from_symbol=EUR&to_symbol=GBP&apikey=123654
#
# contains these information:
#
# - type of info: FX_DAILY
# - from_symbol: EUR
# - to_symbol: GBP
# - apikey: 123654
#
# Some ideas:
#
# - What was the opening price of Tesla TSLA yesterday?
# - What percent of days was the open price higher than close price?
# - How often is the up/down trend from yesterday a good predictor of today?
# - Are some months worse than others every year?

# %%
# Example: currency exchange rates between EUR and GBP in last 4 months
    
# {
#     "Time Series FX (Daily)": {
#         "2019-10-16": {
#             "1. open": "0.8665",
#             "2. high": "0.8674",
#             "3. low": "0.8623",
#             "4. close": "0.8644"
#         },
    
import requests
your_api_key = "abcde" #get it from the above website


url = "https://www.alphavantage.co/query?function=FX_DAILY&from_symbol=EUR&to_symbol=GBP&apikey="+your_api_key
response_currency = requests.request("GET", url)
stock_dictionary = response_currency.json()["Time Series FX (Daily)"]
pp.pprint(stock_dictionary)

# %%
# Example: daily stock value of GOOG since 2004-08-19"

# {
#     "Time Series (Daily)": {
#         "2019-10-15": {
#             "1. open": "1220.4000",
#             "2. high": "1235.9200",
#             "3. low": "1220.4000",
#             "4. close": "1235.5700",
#             "5. volume": "495397"
#         },


import requests
import pprint as pp
your_api_key = "abcde" #get it from the above website

url = "https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&outputsize=full&symbol=GOOG&apikey="+your_api_key
response = requests.request("GET", url)
stock_dictionary = response.json()['Time Series (Daily)']
pp.pprint(stock_dictionary)

# %%
# this is some advanced stuff. Look at the above data and try to figure out what's the data structure this api uses.

#to get just dates, or just values
all_dates = list(stock_dictionary.keys())
all_values = list(stock_dictionary.values())

# to drill into a particular date
print("Google opening for 2014-04-01:", stock_dictionary['2020-10-14']['1. open'])

# %%
# advanced: list comprehention to cycle through a dictionary
["date:" + key + " opened on " + value['1. open']
for (key, value) in stock_dictionary.items()]

# %%
# super extra even more advanced! double list comprehention! + conditions!

# get only open and close values, only for dates in October 2020

[ date + " had "+ key + " at " + value
for (date, values) in stock_dictionary.items()
for (key, value ) in values.items()
if date[0:7] == '2020-10' and  (key == '1. open' or key == '4. close' )
]

# %% [markdown]
# ### IMDB Movie database

# %% [markdown]
# website: http://www.omdbapi.com/
# get api key, 1000 calls limit: http://www.omdbapi.com/apikey.aspx (you'll need to click a link in email)
#
#
# **SEARCH BY TITLE** - http://www.omdbapi.com/?s=Batman - will return basic information about many movies. Each result will contain 10 results in a list. To see next page (11-20) add ```&page=2``` and to see 21-30 add &page=3 etc.
#
# **GET DETAILED INFO BY ID** - http://www.omdbapi.com/?i=tt0372784 - will return detailed information about one movie with the id you pass in the URL, in this example ```tt0372784```
#
# IDEA 1:
# Ask user for a movie title, search for that title in API and print all titles informat "Godzilla (1993)"
#
# IDEA 2:
# Display all movies in detailed format: "Godzilla (1993) - 112 minutes - earned $10.300.000 - Rating: 8.2"
#
# You will need to make two types of calls:
#
# - first get all movies with a particular title (eg "Pokemon" or "Star Wars")
# - in results for that call identify movie id's ```imdbID```
# - FOR EACH imdbID request detailed movie data and display it in a nice format
#
# Some further ideas:
#
# - are there more star wars or star trek movies?
# - Do star wars movies get longer more recently?

# %%
import requests
your_api_key = "abcde" #get it from the above website

url = "http://www.omdbapi.com/?s=Batman&page=1&apikey=" + your_api_key
response = requests.request("GET", url)

# trying to print whole response. If you API key is not correct, this migh have unexpected value
print(response.json()) 


# will give you a list of all Batman movies... all of them? No just first 10.
# there are  'totalResults': '393'! (including cartoons)
# notice in above URL we there is an argument page=1, if you change it to page=2... you get another 10


# {
#   "Search": [
#     {
#       "Title": "Batman Begins",
#       "Year": "2005",
#       "imdbID": "tt0372784",
#       "Type": "movie",
#       "Poster": "https://m.media-amazon.com/images/M/MV5BZmUwNGU2ZmItMmRiNC00MjhlLTg5YWUtODMyNzkxODYzMmZlXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_SX300.jpg"
#     },
#     {
#       "Title": "Batman v Superman: Dawn of Justice",
#       "Year": "2016",
#       "imdbID": "tt2975590",
#       "Type": "movie",
#       "Poster": "https://m.media-amazon.com/images/M/MV5BYThjYzcyYzItNTVjNy00NDk0LTgwMWQtYjMwNmNlNWJhMzMyXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg"
#     },

# %%
# grab just the movies and print just the value of the first one
movies = response.json()["Search"] 
print(movies[0]["Title"])

# %%
import requests
# your_api_key = "abcde" #get it from the above website

url = "http://www.omdbapi.com/?i=tt0372784&apikey={}".format(your_api_key)
response = requests.request("GET", url)
print(response.json()["Actors"])

# will give you a details of a movie with imdb id tt0372784, which is Batman Begins

# {
#   "Title": "Batman Begins",
#   "Year": "2005",
#   "Rated": "PG-13",
#   "Released": "15 Jun 2005",
#   "Runtime": "140 min",
#   "Genre": "Action, Adventure",
#   "Director": "Christopher Nolan",
#   "Writer": "Bob Kane (characters), David S. Goyer (story), Christopher Nolan (screenplay), David S. Goyer (screenplay)",
#   "Actors": "Christian Bale, Michael Caine, Liam Neeson, Katie Holmes",
#   "Plot": "After training with his mentor, Batman begins his fight to free crime-ridden Gotham City from corruption.",
#   "Language": "English, Urdu, Mandarin",
#   "Country": "USA, UK",
#   "Awards": "Nominated for 1 Oscar. Another 14 wins & 72 nominations.",
#   "Poster": "https://m.media-amazon.com/images/M/MV5BZmUwNGU2ZmItMmRiNC00MjhlLTg5YWUtODMyNzkxODYzMmZlXkEyXkFqcGdeQXVyNTIzOTk5ODM@._V1_SX300.jpg",
#   "Ratings": [
#     {
#       "Source": "Internet Movie Database",
#       "Value": "8.2/10"
#     },
#     {
#       "Source": "Rotten Tomatoes",
#       "Value": "84%"
#     },
#     {
#       "Source": "Metacritic",
#       "Value": "70/100"
#     }
#   ],
#   "Metascore": "70",
#   "imdbRating": "8.2",
#   "imdbVotes": "1,212,892",
#   "imdbID": "tt0372784",
#   "Type": "movie",
#   "DVD": "18 Oct 2005",
#   "BoxOffice": "$204,100,000",
#   "Production": "Warner Bros. Pictures",
#   "Website": "N/A",
#   "Response": "True"
# }
